# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/trim-filter-messages.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239435-lesson-4-trim-and-filter-messages)

# %% [markdown]
# # Filtering and trimming messages
#
# ## Review
#
# Now, we have a deeper understanding of a few things:
#
# * How to customize the graph state schema
# * How to define custom state reducers
# * How to use multiple graph state schemas
#
# ## Goals
#
# Now, we can start using these concepts with models in LangGraph!
#
# In the next few sessions, we'll build towards a chatbot that has long-term memory.
#
# Because our chatbot will use messages, let's first talk a bit more about advanced ways to work with messages in graph state.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain_core langgraph langchain_openai

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("GOOGLE_API_KEY")

# %% [markdown]
# We'll use [LangSmith](https://docs.langchain.com/langsmith/home) for [tracing](https://docs.langchain.com/langsmith/observability-concepts).
#
# We'll log to a project, `langchain-academy`.

# %%
_set_env("LANGSMITH_API_KEY")
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langchain-academy"

# %% [markdown]
# ## Messages as state
#
# First, let's define some messages.

# %%
from pprint import pprint
from langchain_core.messages import AIMessage, HumanMessage
messages = [AIMessage(f"So you said you were researching ocean mammals?", name="Bot")]
messages.append(HumanMessage(f"Yes, I know about whales. But what others should I learn about?", name="Lance"))

for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?

# %% [markdown]
# Recall we can pass them to a chat model.

# %%
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", google_api_key=os.environ.get("GOOGLE_API_KEY"))
llm.invoke(messages)
# Out:
# AIMessage(content='That\'s a great starting point! Whales are fascinating. Beyond whales, the ocean is teeming with other incredible marine mammals. Here are some key groups you should definitely learn about:\n\n**1. Dolphins:**\n\n*   **What they are:** Highly intelligent, social, and agile cetaceans (the same order as whales). They are generally smaller than whales.\n*   **Key characteristics:** Known for their playful behavior, complex communication (echolocation and whistles), and diverse species.\n*   **Examples to research:**\n    *   **Bottlenose Dolphin:** The most common and well-known, often seen in aquariums and in the wild.\n    *   **Orca (Killer Whale):** Technically the largest dolphin species! They are apex predators with complex hunting strategies and social structures.\n    *   **Spinner Dolphin:** Famous for their acrobatic leaps and spins.\n    *   **Common Dolphin:** Found in large pods and known for their speed.\n\n**2. Porpoises:**\n\n*   **What they are:** Also cetaceans, closely related to dolphins but generally smaller, more stout, and with different physical features.\n*   **Key characteristics:** They have spade-shaped teeth (dolphins have conical teeth), rounded heads (dolphins often have beaks), and triangular dorsal fins (dolphins often have curved ones). They tend to be more shy than dolphins.\n*   **Examples to research:**\n    *   **Harbor Porpoise:** Common in coastal waters of the Northern Hemisphere.\n    *   **Vaquita:** Critically endangered, found in the Gulf of California, and the smallest porpoise.\n\n**3. Seals:**\n\n*   **What they are:** Pinnipeds, meaning "fin-footed." They are semi-aquatic, spending a lot of time on land or ice for breeding and resting, but hunting in the ocean.\n*   **Key characteristics:** They have flippers for locomotion, can move on land by "galumphing" (using their front flippers and hindquarters), and have fur.\n*   **Examples to research:**\n    *   **Harbor Seal:** Widespread and commonly seen.\n    *   **Grey Seal:** Larger than harbor seals, with distinct facial features.\n    *   **Elephant Seal:** Known for the males\' large, trunk-like noses and their massive size.\n\n**4. Sea Lions:**\n\n*   **What they are:** Also pinnipeds, but distinct from seals.\n*   **Key characteristics:** They can rotate their hind flippers forward, allowing them to "walk" on land more easily than seals. They also have visible external ear flaps (unlike seals). They are often vocal.\n*   **Examples to research:**\n    *   **California Sea Lion:** Very common along the Pacific coast of North America, often seen in harbors.\n    *   **Steller Sea Lion:** The largest sea lion species.\n\n**5. Walruses:**\n\n*   **What they are:** Another type of pinniped, easily recognized by their large tusks and whiskers.\n*   **Key characteristics:** They are found in the Arctic and are highly social. Their tusks are used for defense, hauling themselves out of the water, and social dominance.\n*   **Examples to research:**\n    *   **Pacific Walrus**\n    *   **Atlantic Walrus**\n\n**6. Sea Otters:**\n\n*   **What they are:** The smallest marine mammals in North America and members of the weasel family.\n*   **Key characteristics:** They are found in the North Pacific and are known for their thick fur (the densest of any mammal), their use of tools (like rocks to crack open shellfish), and their habit of holding hands while sleeping to avoid drifting apart.\n*   **Examples to research:**\n    *   **Sea Otter**\n\n**7. Manatees and Dugongs (Sirenians):**\n\n*   **What they are:** Large, slow-moving, herbivorous marine mammals often called "sea cows."\n*   **Key characteristics:** They have paddle-like tails and spend their lives in shallow coastal waters and rivers. They are very gentle.\n*   **Examples to research:**\n    *   **West Indian Manatee**\n    *   **Dugong** (found in the Indian and Pacific Oceans)\n\n**When you research these, consider:**\n\n*   **Habitat:** Where do they live?\n ...

# %% [markdown]
# We can run our chat model in a simple graph with `MessagesState`.

# %%
from IPython.display import Image, display
from langgraph.graph import MessagesState
from langgraph.graph import StateGraph, START, END

# Node
def chat_model_node(state: MessagesState):
    return {"messages": llm.invoke(state["messages"])}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
#display(Image(graph.get_graph().draw_mermaid_png()))
print(graph.get_graph().draw_mermaid())
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	chat_model(chat_model)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> chat_model;
# 	chat_model --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great starting point! Whales are fascinating. Beyond whales, the world of ocean mammals is incredibly diverse and full of amazing creatures. Here are some other groups of marine mammals you should definitely learn about, categorized for easier understanding:
#
# **1. Other Cetaceans (The Whale, Dolphin, and Porpoise Family - Order Cetacea):**
#
# *   **Dolphins:** These are probably the most well-known relatives of whales. They are highly intelligent, social, and often playful. There are many different species, each with unique characteristics.
#     *   **Key examples:** Bottlenose Dolphin, Spinner Dolphin, Orca (Killer Whale - yes, it's a dolphin!), Risso's Dolphin.
#     *   **What to learn:** Their complex social structures, echolocation abilities, communication methods, and diverse hunting strategies.
#
# *   **Porpoises:** Often confused with dolphins, porpoises are generally smaller, have blunter snouts, and lack the prominent "beak" of many dolphins. They also have spade-shaped teeth instead of conical ones.
#     *   **Key examples:** Harbor Porpoise, Dall's Porpoise, Vaquita (critically endangered).
#     *   **What to learn:** Their more elusive nature compared to dolphins, their adaptations for colder waters, and the conservation challenges many species face.
#
# **2. Pinnipeds (The Seal and Sea Lion Family - Order Carnivora, Suborder Pinnipedia):**
#
# *   **True Seals (Phocidae):** These are the seals that "wriggle" on land because they can't rotate their hind flippers forward. They have fur but no external ear flaps.
#     *   **Key examples:** Harbor Seal, Grey Seal, Harp Seal, Elephant Seal, Leopard Seal.
#     *   **What to learn:** Their adaptations for diving, their blubber for insulation, their breeding behaviors, and the different diets of various species.
#
# *   **Eared Seals (Otariidae):** This group includes sea lions and fur seals. They *can* rotate their hind flippers forward, allowing them to "walk" on land. They also have visible external ear flaps.
#     *   **Key examples:** California Sea Lion, Steller Sea Lion, Northern Fur Seal.
#     *   **What to learn:** Their agility on land, their vocalizations (sea lions are known for barking!), and how they hunt in the water.
#
# *   **Walruses (Odobenidae):** A unique group with just one living species. They are easily identifiable by their large tusks (which are elongated canine teeth) and their whiskered snouts.
#     *   **Key examples:** Walrus.
#     *   **What to learn:** The function of their tusks (for defense, hauling out, and breaking ice), their specialized diet of mollusks, and their importance in Arctic ecosystems.
#
# **3. Sea Otters and Marine Otters (Family Mustelidae):**
#
# *   **Sea Otters:** These are the largest members of the weasel family and are adapted to a fully marine life. They are known for their incredibly dense fur and for using tools (like rocks) to open shellfish.
#     *   **Key examples:** Sea Otter (also called Sea Otter).
#     *   **What to learn:** Their remarkable insulation provided by their fur (they don't have blubber), their unique foraging techniques, and their vital role in kelp forest ecosystems.
#
# *   **Marine Otters:** Less known than sea otters, these are smaller and inhabit coastal areas of South America.
#     *   **Key examples:** Marine Otter.
#     *   **What to learn:** Their specific adaptations to coastal environments and their conservation status.
#
# **4. Sirenians (The Manatee and Dugong Family - Order Sirenia):**
#
# *   **Manatees:** Large, slow-moving, herbivorous mammals that inhabit shallow coastal waters and rivers. They have paddle-shaped tails.
#     *   **Key examples:** West Indian Manatee, Amazonian Manatee, West African Manatee.
#     *   **What to learn:** Their gentle nature, their reliance on seagrass and aquatic plants for food, and the threats they face from boat strikes and habitat loss.
#
# *   **Dugongs:** Similar to manatees but found in the Indo-Pacific region. They have a fluke-like tail (similar to a whale's) and are generally found in saltier waters.
#     *   **Key examples:** Dugong.
#     *   **What to learn:** Their diet of seagrass and their cultural significance in some regions.
#
# **5. Polar Bears (Family Ursidae):**
#
# *   While primarily land mammals, polar bears are considered marine mammals because they spend a significant portion of their lives on sea ice and rely on the ocean for their primary food source (seals).
#     *   **Key examples:** Polar Bear.
#     *   **What to learn:** Their incredible adaptations for Arctic life, their hunting strategies, and the profound impact of climate change on their habitat.
#
# **Where to Start Your Research:**
#
# *   **Focus on a specific group:** Pick one of the categories above and dive deep.
# *   **Look up key species:** Once you've chosen a group, research specific examples.
# *   **Consider their habitat:** Where do they live? What are the conditions like?
# *   **Explore their diet and feeding strategies:** How do they get their food? What do they eat?
# *   **Investigate their social behavior:** Are they solitary or do they live in groups? How do they communicate?
# *   **Learn about their adaptations:** What makes them suited to life in the ocean? (e.g., blubber, flippers, echolocation, fur).
# *   **Understand their conservation status:** Are they endangered? What are the threats they face?
#
# This is a fantastic journey you're embarking on! Each of these groups has unique stories and adaptations that will amaze you. Happy researching!

# %% [markdown]
# ## Reducer
#
# A practical challenge when working with messages is managing long-running conversations.
#
# Long-running conversations result in high token usage and latency if we are not careful, because we pass a growing list of messages to the model.
#
# We have a few ways to address this.
#
# First, recall the trick we saw using `RemoveMessage` and the `add_messages` reducer.

# %%
from langchain_core.messages import RemoveMessage

# Nodes
def filter_messages(state: MessagesState):
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"messages": delete_messages}

def chat_model_node(state: MessagesState):    
    return {"messages": [llm.invoke(state["messages"])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("filter", filter_messages)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "filter")
builder.add_edge("filter", "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
# display(Image(graph.get_graph().draw_mermaid_png()))
print(graph.get_graph().draw_mermaid())
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	filter(filter)
# 	chat_model(chat_model)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> filter;
# 	filter --> chat_model;
# 	chat_model --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
# Message list with a preamble
messages = [AIMessage("Hi.", name="Bot", id="1")]
messages.append(HumanMessage("Hi.", name="Lance", id="2"))
messages.append(AIMessage("So you said you were researching ocean mammals?", name="Bot", id="3"))
messages.append(HumanMessage("Yes, I know about whales. But what others should I learn about?", name="Lance", id="4"))

# Invoke
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great question! Beyond whales, the ocean is teeming with fascinating marine mammals. Here are some other groups you should definitely explore:
#
# **1. Dolphins:**
#    * **What to learn:** While often grouped with whales, dolphins are a distinct group. They are known for their intelligence, complex social structures, and playful behavior.
#    * **Examples:** Bottlenose dolphins (very common and well-studied), spinner dolphins (known for their acrobatic leaps), orcas (which are actually the largest dolphin species and often called "killer whales" but are technically dolphins).
#    * **Interesting facts:** Dolphins use echolocation to navigate and hunt, and they have complex communication systems.
#
# **2. Porpoises:**
#    * **What to learn:** Similar to dolphins but generally smaller, with more rounded faces and spade-shaped teeth instead of conical ones. They are often more shy than dolphins.
#    * **Examples:** Harbor porpoises, Dall's porpoises.
#    * **Interesting facts:** They tend to be less interactive with humans and boats than dolphins.
#
# **3. Seals (True Seals):**
#    * **What to learn:** These are earless seals. They use their front flippers for propulsion in the water and move on land by wriggling their bodies.
#    * **Examples:** Harbor seals, elephant seals (known for the male's large proboscis), harp seals.
#    * **Interesting facts:** They can dive to impressive depths and hold their breath for long periods.
#
# **4. Sea Lions:**
#    * **What to learn:** These are eared seals, meaning they have external ear flaps. They can "walk" on land using their large front flippers and hind flippers.
#    * **Examples:** California sea lions, Steller sea lions.
#    * **Interesting facts:** Sea lions are often seen basking on rocks and are known for their vocalizations.
#
# **5. Walruses:**
#    * **What to learn:** Easily recognizable by their long tusks (which are actually elongated canine teeth) and whiskers. They are large, social animals found in Arctic waters.
#    * **Examples:** The Pacific walrus and the Atlantic walrus.
#    * **Interesting facts:** Walruses use their tusks for defense, hauling themselves out of the water, and breaking ice.
#
# **6. Sea Otters:**
#    * **What to learn:** The smallest marine mammals in North America. They have incredibly dense fur for insulation and are known for using tools (like rocks) to crack open shellfish.
#    * **Examples:** Sea otter.
#    * **Interesting facts:** Sea otters often float on their backs, holding hands with each other to avoid drifting apart.
#
# **7. Manatees and Dugongs (Sirenians):**
#    * **What to learn:** These are large, slow-moving, herbivorous marine mammals that live in shallow coastal waters and rivers. They are often called "sea cows."
#    * **Examples:** West Indian manatee, dugong.
#    * **Interesting facts:** They have paddle-like tails and spend most of their time grazing on seagrass. Manatees have a rounder tail, while dugongs have a more fluked tail.
#
# **When researching, consider these aspects for each animal:**
#
# *   **Habitat:** Where do they live? (e.g., Arctic, temperate waters, tropical coasts)
# *   **Diet:** What do they eat? (e.g., fish, squid, crustaceans, plants)
# *   **Social behavior:** Are they solitary or do they live in groups? How do they interact?
# *   **Reproduction:** How do they raise their young?
# *   **Adaptations:** What special features help them survive in the ocean? (e.g., blubber, echolocation, specialized flippers)
# *   **Conservation status:** Are they endangered or threatened? What are the threats they face?
#
# This list should give you a fantastic starting point for expanding your knowledge of ocean mammals beyond whales! Enjoy your research!

# %% [markdown]
# ## Filtering messages
#
# If you don't need or want to modify the graph state, you can just filter the messages you pass to the chat model.
#
# For example, just pass in a filtered list: `llm.invoke(messages[-1:])` to the model.

# %%
# Node
def chat_model_node(state: MessagesState):
    return {"messages": [llm.invoke(state["messages"][-1:])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
#display(Image(graph.get_graph().draw_mermaid_png()))
print(graph.get_graph().draw_mermaid())
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	chat_model(chat_model)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> chat_model;
# 	chat_model --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %% [markdown]
# Let's take our existing list of messages, append the above LLM response, and append a follow-up question.

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me more about Narwhals!", name="Lance"))

# %%
for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great question! Beyond whales, the ocean is teeming with fascinating marine mammals. Here are some other groups you should definitely explore:
#
# **1. Dolphins:**
#    * **What to learn:** While often grouped with whales, dolphins are a distinct group. They are known for their intelligence, complex social structures, and playful behavior.
#    * **Examples:** Bottlenose dolphins (very common and well-studied), spinner dolphins (known for their acrobatic leaps), orcas (which are actually the largest dolphin species and often called "killer whales" but are technically dolphins).
#    * **Interesting facts:** Dolphins use echolocation to navigate and hunt, and they have complex communication systems.
#
# **2. Porpoises:**
#    * **What to learn:** Similar to dolphins but generally smaller, with more rounded faces and spade-shaped teeth instead of conical ones. They are often more shy than dolphins.
#    * **Examples:** Harbor porpoises, Dall's porpoises.
#    * **Interesting facts:** They tend to be less interactive with humans and boats than dolphins.
#
# **3. Seals (True Seals):**
#    * **What to learn:** These are earless seals. They use their front flippers for propulsion in the water and move on land by wriggling their bodies.
#    * **Examples:** Harbor seals, elephant seals (known for the male's large proboscis), harp seals.
#    * **Interesting facts:** They can dive to impressive depths and hold their breath for long periods.
#
# **4. Sea Lions:**
#    * **What to learn:** These are eared seals, meaning they have external ear flaps. They can "walk" on land using their large front flippers and hind flippers.
#    * **Examples:** California sea lions, Steller sea lions.
#    * **Interesting facts:** Sea lions are often seen basking on rocks and are known for their vocalizations.
#
# **5. Walruses:**
#    * **What to learn:** Easily recognizable by their long tusks (which are actually elongated canine teeth) and whiskers. They are large, social animals found in Arctic waters.
#    * **Examples:** The Pacific walrus and the Atlantic walrus.
#    * **Interesting facts:** Walruses use their tusks for defense, hauling themselves out of the water, and breaking ice.
#
# **6. Sea Otters:**
#    * **What to learn:** The smallest marine mammals in North America. They have incredibly dense fur for insulation and are known for using tools (like rocks) to crack open shellfish.
#    * **Examples:** Sea otter.
#    * **Interesting facts:** Sea otters often float on their backs, holding hands with each other to avoid drifting apart.
#
# **7. Manatees and Dugongs (Sirenians):**
#    * **What to learn:** These are large, slow-moving, herbivorous marine mammals that live in shallow coastal waters and rivers. They are often called "sea cows."
#    * **Examples:** West Indian manatee, dugong.
#    * **Interesting facts:** They have paddle-like tails and spend most of their time grazing on seagrass. Manatees have a rounder tail, while dugongs have a more fluked tail.
#
# **When researching, consider these aspects for each animal:**
#
# *   **Habitat:** Where do they live? (e.g., Arctic, temperate waters, tropical coasts)
# *   **Diet:** What do they eat? (e.g., fish, squid, crustaceans, plants)
# *   **Social behavior:** Are they solitary or do they live in groups? How do they interact?
# *   **Reproduction:** How do they raise their young?
# *   **Adaptations:** What special features help them survive in the ocean? (e.g., blubber, echolocation, specialized flippers)
# *   **Conservation status:** Are they endangered or threatened? What are the threats they face?
#
# This list should give you a fantastic starting point for expanding your knowledge of ocean mammals beyond whales! Enjoy your research!
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!

# %%
# Invoke, using message filtering
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great question! Beyond whales, the ocean is teeming with fascinating marine mammals. Here are some other groups you should definitely explore:
#
# **1. Dolphins:**
#    * **What to learn:** While often grouped with whales, dolphins are a distinct group. They are known for their intelligence, complex social structures, and playful behavior.
#    * **Examples:** Bottlenose dolphins (very common and well-studied), spinner dolphins (known for their acrobatic leaps), orcas (which are actually the largest dolphin species and often called "killer whales" but are technically dolphins).
#    * **Interesting facts:** Dolphins use echolocation to navigate and hunt, and they have complex communication systems.
#
# **2. Porpoises:**
#    * **What to learn:** Similar to dolphins but generally smaller, with more rounded faces and spade-shaped teeth instead of conical ones. They are often more shy than dolphins.
#    * **Examples:** Harbor porpoises, Dall's porpoises.
#    * **Interesting facts:** They tend to be less interactive with humans and boats than dolphins.
#
# **3. Seals (True Seals):**
#    * **What to learn:** These are earless seals. They use their front flippers for propulsion in the water and move on land by wriggling their bodies.
#    * **Examples:** Harbor seals, elephant seals (known for the male's large proboscis), harp seals.
#    * **Interesting facts:** They can dive to impressive depths and hold their breath for long periods.
#
# **4. Sea Lions:**
#    * **What to learn:** These are eared seals, meaning they have external ear flaps. They can "walk" on land using their large front flippers and hind flippers.
#    * **Examples:** California sea lions, Steller sea lions.
#    * **Interesting facts:** Sea lions are often seen basking on rocks and are known for their vocalizations.
#
# **5. Walruses:**
#    * **What to learn:** Easily recognizable by their long tusks (which are actually elongated canine teeth) and whiskers. They are large, social animals found in Arctic waters.
#    * **Examples:** The Pacific walrus and the Atlantic walrus.
#    * **Interesting facts:** Walruses use their tusks for defense, hauling themselves out of the water, and breaking ice.
#
# **6. Sea Otters:**
#    * **What to learn:** The smallest marine mammals in North America. They have incredibly dense fur for insulation and are known for using tools (like rocks) to crack open shellfish.
#    * **Examples:** Sea otter.
#    * **Interesting facts:** Sea otters often float on their backs, holding hands with each other to avoid drifting apart.
#
# **7. Manatees and Dugongs (Sirenians):**
#    * **What to learn:** These are large, slow-moving, herbivorous marine mammals that live in shallow coastal waters and rivers. They are often called "sea cows."
#    * **Examples:** West Indian manatee, dugong.
#    * **Interesting facts:** They have paddle-like tails and spend most of their time grazing on seagrass. Manatees have a rounder tail, while dugongs have a more fluked tail.
#
# **When researching, consider these aspects for each animal:**
#
# *   **Habitat:** Where do they live? (e.g., Arctic, temperate waters, tropical coasts)
# *   **Diet:** What do they eat? (e.g., fish, squid, crustaceans, plants)
# *   **Social behavior:** Are they solitary or do they live in groups? How do they interact?
# *   **Reproduction:** How do they raise their young?
# *   **Adaptations:** What special features help them survive in the ocean? (e.g., blubber, echolocation, specialized flippers)
# *   **Conservation status:** Are they endangered or threatened? What are the threats they face?
#
# This list should give you a fantastic starting point for expanding your knowledge of ocean mammals beyond whales! Enjoy your research!
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!
# ================================== Ai Message ==================================
#
# Narwhals are truly one of the most fascinating and unique creatures in the ocean! They're often called the "unicorns of the sea" for a very good reason. Let's dive into what makes them so special:
#
# **The Iconic Tusk:**
#
# *   **What is it?** The most striking feature of the narwhal is the **long, spiraled tusk** that protrudes from the upper jaw of males (and occasionally, very rarely, females). This tusk can grow up to 10 feet long, making it longer than the narwhal's body itself!
# *   **Not a horn!** Despite the "unicorn" comparison, it's not a horn. It's actually an **enlarged canine tooth**.
# *   **What's its purpose?** This is where it gets really interesting, and scientists are still unraveling its mysteries. The leading theories suggest it's used for:
#     *   **Sensory Organ:** The tusk is packed with millions of nerve endings, making it incredibly sensitive. It's believed to detect changes in water temperature, salinity, pressure, and even the presence of prey. Imagine it as a sophisticated sonar device!
#     *   **Mating Rituals/Display:** Males often use their tusks in ritualistic "tusking" behaviors, where they rub their tusks together. This could be a way to establish dominance, assess the health and strength of rivals, or even impress females.
#     *   **Breaking Ice:** Some theories suggest it might be used to break through thin ice to create breathing holes, though this is less widely accepted as a primary function.
#     *   **Hunting:** While not its primary function, some observations suggest narwhals might use their tusks to stun fish.
#
# **Appearance and Biology:**
#
# *   **Size:** Narwhals are medium-sized toothed whales, typically ranging from 13 to 20 feet long and weighing between 1,700 to 3,500 pounds.
# *   **Coloration:** They are born a uniform dark gray. As they age, their skin becomes mottled with white spots, eventually turning almost entirely white in older individuals. This camouflage helps them blend in with the icy Arctic waters.
# *   **Dorsal Fin (or lack thereof):** Unlike many whales, narwhals have a very small dorsal ridge instead of a prominent fin. This is an adaptation to avoid injury from ice floes.
# *   **Diet:** They are carnivores and primarily feed on fish like Arctic cod, Greenland halibut, and squid. They hunt by echolocation, using sound waves to locate their prey in the dark, deep waters.
# *   **Social Behavior:** Narwhals are highly social animals, often found in pods of 10-20 individuals, but sometimes gathering in much larger aggregations, especially during migration.
#
# **Habitat and Distribution:**
#
# *   **Arctic Dwellers:** Narwhals are exclusively found in the Arctic waters, primarily in Canada, Greenland, Norway, and Russia.
# *   **Cold Water Specialists:** They thrive in the cold, icy environments, often spending their lives near pack ice.
# *   **Diving Prowess:** They are incredible divers, capable of reaching depths of over 5,000 feet and staying underwater for up to 25 minutes. This allows them to access deep-sea prey.
#
# **Conservation Status and Threats:**
#
# *   **Near Threatened:** Narwhals are currently listed as "Near Threatened" by the IUCN.
# *   **Climate Change:** The biggest threat they face is climate change, which is leading to the melting of Arctic sea ice. This impacts their hunting grounds, migration patterns, and ability to find breathing holes.
# *   **Hunting:** In some regions, indigenous communities have a long history of subsistence hunting of narwhals.
# *   **Pollution:** Plastic pollution and chemical contaminants are also concerns for their health.
# *   **Noise Pollution:** Increased shipping and industrial activity in the Arctic can disrupt their echolocation and communication.
#
# **Interesting Facts:**
#
# *   **"Narwhal" Origin:** The name "narwhal" is believed to come from the Old Norse word "nar," meaning "corpse," likely referring to their pale, mottled appearance.
# *   **No Teeth (Except the Tusk):** Apart from the two tusks in males (and rarely females), narwhals have very few other functional teeth.
# *   **Singing Whales:** Like many whales, narwhals communicate through a variety of clicks, whistles, and pulsed calls.
# *   **Long Migrations:** They undertake long seasonal migrations between their summer feeding grounds and their wintering grounds.
#
# Narwhals are a testament to the incredible diversity and adaptability of life on Earth. Their unique tusk and their resilience in the harsh Arctic environment make them a captivating species that deserves our continued study and protection.

# %% [markdown]
# The state has all of the mesages.
#
# But, let's look at the LangSmith trace to see that the model invocation only uses the last message:
#
# https://smith.langchain.com/public/75aca3ce-ef19-4b92-94be-0178c7a660d9/r

# %% [markdown]
# ## Trim messages
#
# Another approach is to [trim messages](https://docs.langchain.com/oss/python/langgraph/add-memory#trim-messages), based upon a set number of tokens.
#
# This restricts the message history to a specified number of tokens.
#
# While filtering only returns a post-hoc subset of the messages between agents, trimming restricts the number of tokens that a chat model can use to respond.
#
# See the `trim_messages` below.

# %%
from langchain_core.messages import trim_messages

# Node
def chat_model_node(state: MessagesState):
    messages = trim_messages(
            state["messages"],
            max_tokens=100,
            strategy="last",
            token_counter=ChatOpenAI(model="gpt-4o"),
            allow_partial=False,
        )
    return {"messages": [llm.invoke(messages)]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
print(graph.get_graph().draw_mermaid())
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	chat_model(chat_model)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> chat_model;
# 	chat_model --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me where Orcas live!", name="Lance"))

# %%
# Example of trimming messages
trim_messages(
            messages,
            max_tokens=100,
            strategy="last",
            token_counter=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", google_api_key=os.environ.get("GOOGLE_API_KEY")),
            allow_partial=False
        )
# Out:
# [HumanMessage(content='Tell me where Orcas live!', additional_kwargs={}, response_metadata={}, name='Lance')]

# %%
# Invoke, using message trimming in the chat_model_node 
messages_out_trim = graph.invoke({'messages': messages})

# %% [markdown]
# Let's look at the LangSmith trace to see the model invocation:
#
# https://smith.langchain.com/public/b153f7e9-f1a5-4d60-8074-f0d7ab5b42ef/r
